# %% [markdown]
# # Regression Models with cuML, scikit-learn, and XGBoost
# This notebook demonstrates how to build and evaluate various regression models using cuML for GPU acceleration, scikit-learn for Partial Least Squares Regression, and XGBoost.

# %%
import numpy as np
import cuml
import cupy as cp
from cuml.linear_model import LinearRegression as cuLinearRegression
from cuml.linear_model import Lasso as cuLasso
from cuml.linear_model import Ridge as cuRidge
from cuml.linear_model import ElasticNet as cuElasticNet
from cuml.svm import SVR as cuSVR
from cuml.neighbors import KNeighborsRegressor as cuKNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split as TTS
from sklearn.preprocessing import StandardScaler
import os
os.chdir("/local-scratch/GlucoseProject/mobicom23_mobispectral/regression")
import sys
sys.path.append(os.getcwd())
from utils import prepare_data, evaluate_image, load_model, save_model

# %%
data_root = '../datasets/dataset_skin/regression'
file_train = 'concatset_train.txt'
file_test = 'concatset_test.txt'
step = 1

# %%
X_train, y_train, X_test, y_test, test_data = prepare_data(data_root, file_train, file_test, step)
X_train, X_val, y_train, y_val = TTS(X_train, y_train, test_size=0.3, random_state=42)

# %%
# scaler = MinMaxScaler()
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = cp.array(X_train)
X_test = cp.array(X_test)

# %%
# Linear Regression
lin_reg = cuLinearRegression()
lin_reg.fit(X_train, y_train)
y_pred_lin = cp.asnumpy(lin_reg.predict(X_test))
mse_lin = mean_squared_error(y_test, y_pred_lin)
evaluate_image(test_data, model=lin_reg)

# %%
# Lasso Regression
lasso_reg = cuLasso()
lasso_reg.fit(X_train, y_train)
y_pred_lasso = cp.asnumpy(lasso_reg.predict(X_test))
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
evaluate_image(test_data, model=lasso_reg)

# %%
# Ridge Regression
ridge_reg = cuRidge()
ridge_reg.fit(X_train, y_train)
y_pred_ridge = cp.asnumpy(ridge_reg.predict(X_test))
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
evaluate_image(test_data, model=ridge_reg)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Ridge Regression
#       2 ridge_reg = cuRidge()
# ----> 3 ridge_reg.fit(X_train, y_train)
#       4 y_pred_ridge = cp.asnumpy(ridge_reg.predict(X_test))
#       5 mse_ridge = mean_squared_error(y_test, y_pred_ridge)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:188, in _make_decorator_function.<locals>.decorator_function.<locals>.decorator_closure.<locals>.wrapper(*args, **kwargs)
#     185     set_api_output_dtype(output_dtype)
#     187 if process_return:
# --> 188     ret = func(*args, **kwargs)
#     189 else:
#     190     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:393, in enable_device_interop.<locals>.dispatch(self, *args, **kwargs)
#     391 if hasattr(self, "dispatch_func"):
#     392     func_name = gpu_func.__name__
# --> 393     return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#     394 else:
#     395     return gpu_func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:190, in _make_decorator_function.<locals>.decorator_function.<locals>.decorator_closure.<locals>.wrapper(*args, **kwargs)
#     188         ret = func(*args, **kwargs)
#     189     else:
# --> 190         return func(*args, **kwargs)
#     192 return cm.process_return(ret)
#
# File base.pyx:687, in cuml.internals.base.UniversalBase.dispatch_func()
#
# File ridge.pyx:254, in cuml.linear_model.ridge.Ridge.fit()
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/input_utils.py:380, in input_to_cuml_array(X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#     292 @nvtx_annotate(
#     293     message="common.input_utils.input_to_cuml_array",
#     294     category="utils",
#    (...)
#     309     force_contiguous=True,
#     310 ):
#     311     """
#     312     Convert input X to CumlArray.
#     313
#    (...)
#     378
#     379     """
# --> 380     arr = CumlArray.from_input(
#     381         X,
#     382         order=order,
#     383         deepcopy=deepcopy,
#     384         check_dtype=check_dtype,
#     385         convert_to_dtype=convert_to_dtype,
#     386         check_mem_type=check_mem_type,
#     387         convert_to_mem_type=convert_to_mem_type,
#     388         safe_dtype_conversion=safe_dtype_conversion,
#     389         check_cols=check_cols,
#     390         check_rows=check_rows,
#     391         fail_on_order=fail_on_order,
#     392         force_contiguous=force_contiguous,
#     393     )
#     394     try:
#     395         shape = arr.__cuda_array_interface__["shape"]
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/memory_utils.py:87, in with_cupy_rmm.<locals>.cupy_rmm_wrapper(*args, **kwargs)
#      85 if GPU_ENABLED:
#      86     with cupy_using_allocator(rmm_cupy_allocator):
# ---> 87         return func(*args, **kwargs)
#      88 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/array.py:1171, in CumlArray.from_input(cls, X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#    1165 make_copy = force_contiguous and not arr.is_contiguous
#    1167 if (
#    1168     not fail_on_order and order != arr.order and order != "K"
#    1169 ) or make_copy:
#    1170     arr = cls(
# -> 1171         arr.mem_type.xpy.array(
#    1172             arr.to_output("array"), order=order, copy=make_copy
#    1173         ),
#    1174         index=index,
#    1175     )
#    1177 n_rows = arr.shape[0]
#    1179 if len(arr.shape) > 1:
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cupy/_creation/from_data.py:53, in array(obj, dtype, copy, order, subok, ndmin, blocking)
#       7 def array(obj, dtype=None, copy=True, order='K', subok=False, ndmin=0, *,
#       8           blocking=False):
#       9     """Creates an array on the current device.
#      10
#      11     This function currently does not support the ``subok`` option.
#    (...)
#      51
#      52     """
# ---> 53     return _core.array(obj, dtype, copy, order, subok, ndmin, blocking)
#
# File cupy/_core/core.pyx:2379, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2389, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2420, in cupy._core.core._array_from_cupy_ndarray()
#
# File cupy/_core/core.pyx:512, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:570, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:132, in cupy._core.core.ndarray.__new__()
#
# File cupy/_core/core.pyx:220, in cupy._core.core._ndarray_base._init()
#
# File cupy/cuda/memory.pyx:738, in cupy.cuda.memory.alloc()
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/rmm/allocators/cupy.py:37, in rmm_cupy_allocator(nbytes)
#      34     raise ModuleNotFoundError("No module named 'cupy'")
#      36 stream = Stream(obj=cupy.cuda.get_current_stream())
# ---> 37 buf = librmm.device_buffer.DeviceBuffer(size=nbytes, stream=stream)
#      38 dev_id = -1 if buf.ptr else cupy.cuda.device.get_device_id()
#      39 mem = cupy.cuda.UnownedMemory(
#      40     ptr=buf.ptr, size=buf.size, owner=buf, device_id=dev_id
#      41 )
#
# File device_buffer.pyx:85, in rmm._lib.device_buffer.DeviceBuffer.__cinit__()
#
# MemoryError: std::bad_alloc: out_of_memory: CUDA error at: /__w/cuml/cuml/python/build/cp310-cp310-manylinux_2_17_x86_64/_deps/rmm-src/include/rmm/mr/device/cuda_memory_resource.hpp:60: cudaErrorMemoryAllocation out of memory

# %%
# Elastic Net
elastic_net = cuElasticNet()
elastic_net.fit(X_train, y_train)
y_pred_elastic = cp.asnumpy(elastic_net.predict(X_test))
mse_elastic = mean_squared_error(y_test, y_pred_elastic)
evaluate_image(test_data, model=elastic_net)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Elastic Net
#       2 elastic_net = cuElasticNet()
# ----> 3 elastic_net.fit(X_train, y_train)
#       4 y_pred_elastic = cp.asnumpy(elastic_net.predict(X_test))
#       5 mse_elastic = mean_squared_error(y_test, y_pred_elastic)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:188, in _make_decorator_function.<locals>.decorator_function.<locals>.decorator_closure.<locals>.wrapper(*args, **kwargs)
#     185     set_api_output_dtype(output_dtype)
#     187 if process_return:
# --> 188     ret = func(*args, **kwargs)
#     189 else:
#     190     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:393, in enable_device_interop.<locals>.dispatch(self, *args, **kwargs)
#     391 if hasattr(self, "dispatch_func"):
#     392     func_name = gpu_func.__name__
# --> 393     return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#     394 else:
#     395     return gpu_func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:190, in _make_decorator_function.<locals>.decorator_function.<locals>.decorator_closure.<locals>.wrapper(*args, **kwargs)
#     188         ret = func(*args, **kwargs)
#     189     else:
# --> 190         return func(*args, **kwargs)
#     192 return cm.process_return(ret)
#
# File base.pyx:687, in cuml.internals.base.UniversalBase.dispatch_func()
#
# File elastic_net.pyx:252, in cuml.linear_model.elastic_net.ElasticNet.fit()
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:188, in _make_decorator_function.<locals>.decorator_function.<locals>.decorator_closure.<locals>.wrapper(*args, **kwargs)
#     185     set_api_output_dtype(output_dtype)
#     187 if process_return:
# --> 188     ret = func(*args, **kwargs)
#     189 else:
#     190     return func(*args, **kwargs)
#
# File cd.pyx:230, in cuml.solvers.cd.CD.fit()
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/input_utils.py:380, in input_to_cuml_array(X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#     292 @nvtx_annotate(
#     293     message="common.input_utils.input_to_cuml_array",
#     294     category="utils",
#    (...)
#     309     force_contiguous=True,
#     310 ):
#     311     """
#     312     Convert input X to CumlArray.
#     313
#    (...)
#     378
#     379     """
# --> 380     arr = CumlArray.from_input(
#     381         X,
#     382         order=order,
#     383         deepcopy=deepcopy,
#     384         check_dtype=check_dtype,
#     385         convert_to_dtype=convert_to_dtype,
#     386         check_mem_type=check_mem_type,
#     387         convert_to_mem_type=convert_to_mem_type,
#     388         safe_dtype_conversion=safe_dtype_conversion,
#     389         check_cols=check_cols,
#     390         check_rows=check_rows,
#     391         fail_on_order=fail_on_order,
#     392         force_contiguous=force_contiguous,
#     393     )
#     394     try:
#     395         shape = arr.__cuda_array_interface__["shape"]
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/memory_utils.py:87, in with_cupy_rmm.<locals>.cupy_rmm_wrapper(*args, **kwargs)
#      85 if GPU_ENABLED:
#      86     with cupy_using_allocator(rmm_cupy_allocator):
# ---> 87         return func(*args, **kwargs)
#      88 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/array.py:1171, in CumlArray.from_input(cls, X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#    1165 make_copy = force_contiguous and not arr.is_contiguous
#    1167 if (
#    1168     not fail_on_order and order != arr.order and order != "K"
#    1169 ) or make_copy:
#    1170     arr = cls(
# -> 1171         arr.mem_type.xpy.array(
#    1172             arr.to_output("array"), order=order, copy=make_copy
#    1173         ),
#    1174         index=index,
#    1175     )
#    1177 n_rows = arr.shape[0]
#    1179 if len(arr.shape) > 1:
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cupy/_creation/from_data.py:53, in array(obj, dtype, copy, order, subok, ndmin, blocking)
#       7 def array(obj, dtype=None, copy=True, order='K', subok=False, ndmin=0, *,
#       8           blocking=False):
#       9     """Creates an array on the current device.
#      10
#      11     This function currently does not support the ``subok`` option.
#    (...)
#      51
#      52     """
# ---> 53     return _core.array(obj, dtype, copy, order, subok, ndmin, blocking)
#
# File cupy/_core/core.pyx:2379, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2389, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2420, in cupy._core.core._array_from_cupy_ndarray()
#
# File cupy/_core/core.pyx:512, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:570, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:132, in cupy._core.core.ndarray.__new__()
#
# File cupy/_core/core.pyx:220, in cupy._core.core._ndarray_base._init()
#
# File cupy/cuda/memory.pyx:738, in cupy.cuda.memory.alloc()
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/rmm/allocators/cupy.py:37, in rmm_cupy_allocator(nbytes)
#      34     raise ModuleNotFoundError("No module named 'cupy'")
#      36 stream = Stream(obj=cupy.cuda.get_current_stream())
# ---> 37 buf = librmm.device_buffer.DeviceBuffer(size=nbytes, stream=stream)
#      38 dev_id = -1 if buf.ptr else cupy.cuda.device.get_device_id()
#      39 mem = cupy.cuda.UnownedMemory(
#      40     ptr=buf.ptr, size=buf.size, owner=buf, device_id=dev_id
#      41 )
#
# File device_buffer.pyx:85, in rmm._lib.device_buffer.DeviceBuffer.__cinit__()
#
# MemoryError: std::bad_alloc: out_of_memory: CUDA error at: /__w/cuml/cuml/python/build/cp310-cp310-manylinux_2_17_x86_64/_deps/rmm-src/include/rmm/mr/device/cuda_memory_resource.hpp:60: cudaErrorMemoryAllocation out of memory

# %%
# Multi-Layer Perceptron
mlp_reg = MLPRegressor()
mlp_reg.fit(cp.asnumpy(X_train), cp.asnumpy(y_train))
y_pred_mlp = mlp_reg.predict(cp.asnumpy(X_test))
mse_mlp = mean_squared_error(y_test, y_pred_mlp)
evaluate_image(test_data, model=mlp_reg)

# %%
# KNN
knn_reg = cuKNeighborsRegressor()
knn_reg.fit(X_train, y_train)
y_pred_knn = cp.asnumpy(knn_reg.predict(X_test))
mse_knn = mean_squared_error(y_test, y_pred_knn)
evaluate_image(test_data, model=knn_reg)

# %%
# Partial Least Squares
pls_reg = PLSRegression()
pls_reg.fit(cp.asnumpy(X_train), cp.asnumpy(y_train))
y_pred_pls = pls_reg.predict(cp.asnumpy(X_test))
mse_pls = mean_squared_error(y_test, y_pred_pls)
evaluate_image(test_data, model=pls_reg)

# %%
# XGBoost
xgb_reg = XGBRegressor(device='cuda', tree_method='hist')
xgb_reg.fit(X_train, y_train)
y_pred_xgb = cp.asnumpy(xgb_reg.predict(X_test))
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
evaluate_image(test_data, model=xgb_reg)

# %%
# Support Vector Regressor
svr_reg = cuSVR()
svr_reg.fit(X_train, y_train)
y_pred_svr = cp.asnumpy(svr_reg.predict(X_test))
mse_svr = mean_squared_error(y_test, y_pred_svr)
evaluate_image(test_data, model=svr_reg)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Support Vector Regressor
#       2 svr_reg = cuSVR()
# ----> 3 svr_reg.fit(X_train, y_train)
#       4 y_pred_svr = cp.asnumpy(svr_reg.predict(X_test))
#       5 mse_svr = mean_squared_error(y_test, y_pred_svr)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/api_decorators.py:188, in _make_decorator_function.<locals>.decorator_function.<locals>.decorator_closure.<locals>.wrapper(*args, **kwargs)
#     185     set_api_output_dtype(output_dtype)
#     187 if process_return:
# --> 188     ret = func(*args, **kwargs)
#     189 else:
#     190     return func(*args, **kwargs)
#
# File svr.pyx:269, in cuml.svm.svr.SVR.fit()
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/input_utils.py:380, in input_to_cuml_array(X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#     292 @nvtx_annotate(
#     293     message="common.input_utils.input_to_cuml_array",
#     294     category="utils",
#    (...)
#     309     force_contiguous=True,
#     310 ):
#     311     """
#     312     Convert input X to CumlArray.
#     313
#    (...)
#     378
#     379     """
# --> 380     arr = CumlArray.from_input(
#     381         X,
#     382         order=order,
#     383         deepcopy=deepcopy,
#     384         check_dtype=check_dtype,
#     385         convert_to_dtype=convert_to_dtype,
#     386         check_mem_type=check_mem_type,
#     387         convert_to_mem_type=convert_to_mem_type,
#     388         safe_dtype_conversion=safe_dtype_conversion,
#     389         check_cols=check_cols,
#     390         check_rows=check_rows,
#     391         fail_on_order=fail_on_order,
#     392         force_contiguous=force_contiguous,
#     393     )
#     394     try:
#     395         shape = arr.__cuda_array_interface__["shape"]
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/memory_utils.py:87, in with_cupy_rmm.<locals>.cupy_rmm_wrapper(*args, **kwargs)
#      85 if GPU_ENABLED:
#      86     with cupy_using_allocator(rmm_cupy_allocator):
# ---> 87         return func(*args, **kwargs)
#      88 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cuml/internals/array.py:1171, in CumlArray.from_input(cls, X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#    1165 make_copy = force_contiguous and not arr.is_contiguous
#    1167 if (
#    1168     not fail_on_order and order != arr.order and order != "K"
#    1169 ) or make_copy:
#    1170     arr = cls(
# -> 1171         arr.mem_type.xpy.array(
#    1172             arr.to_output("array"), order=order, copy=make_copy
#    1173         ),
#    1174         index=index,
#    1175     )
#    1177 n_rows = arr.shape[0]
#    1179 if len(arr.shape) > 1:
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/cupy/_creation/from_data.py:53, in array(obj, dtype, copy, order, subok, ndmin, blocking)
#       7 def array(obj, dtype=None, copy=True, order='K', subok=False, ndmin=0, *,
#       8           blocking=False):
#       9     """Creates an array on the current device.
#      10
#      11     This function currently does not support the ``subok`` option.
#    (...)
#      51
#      52     """
# ---> 53     return _core.array(obj, dtype, copy, order, subok, ndmin, blocking)
#
# File cupy/_core/core.pyx:2379, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2389, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2420, in cupy._core.core._array_from_cupy_ndarray()
#
# File cupy/_core/core.pyx:512, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:570, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:132, in cupy._core.core.ndarray.__new__()
#
# File cupy/_core/core.pyx:220, in cupy._core.core._ndarray_base._init()
#
# File cupy/cuda/memory.pyx:738, in cupy.cuda.memory.alloc()
#
# File ~/miniconda3/envs/Glucose/lib/python3.10/site-packages/rmm/allocators/cupy.py:37, in rmm_cupy_allocator(nbytes)
#      34     raise ModuleNotFoundError("No module named 'cupy'")
#      36 stream = Stream(obj=cupy.cuda.get_current_stream())
# ---> 37 buf = librmm.device_buffer.DeviceBuffer(size=nbytes, stream=stream)
#      38 dev_id = -1 if buf.ptr else cupy.cuda.device.get_device_id()
#      39 mem = cupy.cuda.UnownedMemory(
#      40     ptr=buf.ptr, size=buf.size, owner=buf, device_id=dev_id
#      41 )
#
# File device_buffer.pyx:85, in rmm._lib.device_buffer.DeviceBuffer.__cinit__()
#
# MemoryError: std::bad_alloc: out_of_memory: CUDA error at: /__w/cuml/cuml/python/build/cp310-cp310-manylinux_2_17_x86_64/_deps/rmm-src/include/rmm/mr/device/cuda_memory_resource.hpp:60: cudaErrorMemoryAllocation out of memory

# %%
# Print the Mean Squared Error for each model
print("Mean Squared Error for Linear Regression:", mse_lin)
print("Mean Squared Error for Lasso Regression:", mse_lasso)
print("Mean Squared Error for Ridge Regression:", mse_ridge)
print("Mean Squared Error for Elastic Net:", mse_elastic)
print("Mean Squared Error for MLP:", mse_mlp)
print("Mean Squared Error for SVR:", mse_svr)
print("Mean Squared Error for XGBoost:", mse_xgb)
print("Mean Squared Error for PLS:", mse_pls)
# Out:
# Mean Squared Error for Linear Regression: 642.42444
# Mean Squared Error for Lasso Regression: 681.0681
# Mean Squared Error for Ridge Regression: 642.4102
# Mean Squared Error for Elastic Net: 697.01
# Mean Squared Error for MLP: 467.83594
# Mean Squared Error for SVR: 566.8638
# Mean Squared Error for XGBoost: 481.72345
# Mean Squared Error for PLS: 684.3225786455827

# %%
# Trained PLS based on S1 and S2
model = load_model('Models/PLS_regressor1.model')
evaluate_image(test_data, model=model)

# %%
# PLSR
# Best parameter: tol: 1e-06, scale: False, n_components: 20, max_iter: 500
